# %%
# %pip install openai groq python-dotenv -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from openai import OpenAI
from groq import Groq
from dotenv import load_dotenv

load_dotenv()

client = Groq(
    api_key=os.getenv("GROQ_API_KEY")
)

while True:

    question = input("Ask your agent: ")

    if question.lower() == "exit":
        break

    response = client.chat.completions.create(
        model="groq/compound",
        messages=[
            {"role": "system", "content": "You are an AI agent that answers questions"},
            {"role": "user", "content": question}
        ]
    )

    print("Agent:", response.choices[0].message.content)
# Out:
# Agent: Hey there! How can I help you today?
# Agent: I’m called **Compound**—an AI system built by Groq.
